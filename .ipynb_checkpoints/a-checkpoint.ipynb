# %%
! pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/lib/python3.7/site-packages (0.10.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from folium) (1.17.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.7/site-packages (from folium) (2.10.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/lib/python3.7/site-packages (from folium) (0.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from branca>=0.3.0->folium) (1.12.0)

# %%
import folium
import pandas as pd
import numpy as np
import random 
import warnings
warnings.filterwarnings('ignore')

# %%
user_nbhd = input('Choose from Manhattan, Brooklyn, Queens, Bronx, Staten Island: ')
user_nhhd_result = airbnb_data[airbnb_data['neighbourhood_group'] == user_nbhd]
print(user_nhhd_result.sample(2))

# %%
CENTER_NYC = (40.7128,-74.0060)
map = folium.Map(location=CENTER_NYC, zoom_start=12)
map
for row in data.to_records():
    pos = (row['latitude'],row['longitude'])
    marker = folium.Marker(location=pos, 
                    popup="%s, %s" % (row['name'],row['neighbourhood_ground'])
                          )
    map.add_child(marker)
map

# %%
restaurants = pd.read_csv('NYC_Restaurants.csv')
restaurants.sample(5)
# Out:
#                            NAME       BORO BUILDING              STREET  \
# 217662  FRATELLI'S PIZZA & CAFE      BRONX      404  HUNTS POINT AVENUE
# 108445         DESMOND'S TAVERN  MANHATTAN      433   PARK AVENUE SOUTH
# 356433  FRESNILLENSE RESTAURANT   BROOKLYN     2004            BATH AVE
# 333790     NEW METRO SUSHI CAFE     QUEENS    11821    METROPOLITAN AVE
# 212138       EL JAYA RESTAURANT  MANHATTAN     8385      AUDUBON AVENUE
#
#         ZIPCODE                                CUISINE DESCRIPTION  \
# 217662  10474.0                                      Pizza/Italian
# 108445  10016.0                                           American
# 356433  11214.0                                            Mexican
# 333790  11415.0                                           Japanese
# 212138  10032.0  Latin (Cuban, Dominican, Puerto Rican, South &...
#
#         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 217662         NaN         NaN         NaN         NaN          NaN
# 108445         NaN         NaN         NaN         NaN          NaN
# 356433         NaN         NaN         NaN         NaN          NaN
# 333790         NaN         NaN         NaN         NaN          NaN
# 212138         NaN         NaN         NaN         NaN          NaN
#
#         Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15
# 217662          NaN          NaN          NaN          NaN          NaN
# 108445          NaN          NaN          NaN          NaN          NaN
# 356433          NaN          NaN          NaN          NaN          NaN
# 333790          NaN          NaN          NaN          NaN          NaN
# 212138          NaN          NaN          NaN          NaN          NaN

# %%
# Out:
#            CAMIS                                         DBA       BORO  \
# 288614  50009465  HILTON GARDEN INN- MANHATTAN- MIDTOWN EAST  MANHATTAN
# 289769  41716001                   U.S KENNEDY FRIED CHICKEN      BRONX
# 266833  41039229                         CROWN FRIED CHICKEN     QUEENS
# 71737   50048616                        THE TRADE UNION CAFE   BROOKLYN
# 149263  50036472                         CROWN FRIED CHICKEN   BROOKLYN
#
#        BUILDING                 STREET  ZIPCODE       PHONE  \
# 288614      206              E 52ND ST  10022.0  2127946000
# 289769     1761      UNIVERSITY AVENUE  10453.0  7187166430
# 266833    10302  SPRINGFIELD BOULEVARD  11429.0  7187361342
# 71737       346         MALCOLM X BLVD  11233.0  3477153936
# 149263     3402             CHURCH AVE  11203.0  7184843377
#
#        CUISINE DESCRIPTION INSPECTION DATE  \
# 288614            American      08/13/2014
# 289769             Chicken      03/12/2016
# 266833             Chicken      03/09/2017
# 71737     Caf̩/Coffee/Tea      03/27/2017
# 149263             Chicken      03/30/2016
#
#                                                  ACTION VIOLATION CODE  \
# 288614  Violations were cited in the following area(s).            06D
# 289769  Violations were cited in the following area(s).            06A
# 266833  Violations were cited in the following area(s).            05H
# 71737   Violations were cited in the following area(s).            06C
# 149263  Violations were cited in the following area(s).            10E
#
#                                     VIOLATION DESCRIPTION CRITICAL FLAG  \
# 288614  Food contact surface not properly washed, rins...      Critical
# 289769  Personal cleanliness inadequate. Outer garment...      Critical
# 266833  No facilities available to wash, rinse and san...      Critical
# 71737   Food not protected from potential source of co...      Critical
# 149263  Accurate thermometer not provided in refrigera...  Not Critical
#
#         SCORE GRADE  GRADE DATE RECORD DATE  \
# 288614   10.0   NaN         NaN  08/28/2017
# 289769   18.0   NaN         NaN  08/28/2017
# 266833   17.0   NaN         NaN  08/28/2017
# 71737    21.0   NaN         NaN  08/28/2017
# 149263    9.0     A  03/30/2016  08/28/2017
#
#                                       INSPECTION TYPE
# 288614  Pre-permit (Operational) / Initial Inspection
# 289769          Cycle Inspection / Initial Inspection
# 266833          Cycle Inspection / Initial Inspection
# 71737           Cycle Inspection / Initial Inspection
# 149263               Cycle Inspection / Re-inspection
